# %%
import pandas as pd
import os
import sys
sys.path.insert(0, os.getenv("PROJECT_DIR"))
INPUT_PATH = "./../input"
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("./../input/public/test/test.csv")

# %%
from src.db.services import DBServices

# %%
db = DBServices()
df = db.table_load(schema="public", table_name="train")

# %%
df
# Out:
#       index  passenger_id  survived  pclass  \
# 0         0             1         0       3
# 1         0             1         0       3
# 2         0             1         0       3
# 3         0             1         0       3
# 4         1             2         1       1
# ...     ...           ...       ...     ...
# 3559    889           890         1       1
# 3560    890           891         0       3
# 3561    890           891         0       3
# 3562    890           891         0       3
# 3563    890           891         0       3
#
#                                                    name     sex   age  sib_sp  \
# 0                               Braund, Mr. Owen Harris    male  22.0       1
# 1                               Braund, Mr. Owen Harris    male  22.0       1
# 2                               Braund, Mr. Owen Harris    male  22.0       1
# 3                               Braund, Mr. Owen Harris    male  22.0       1
# ...

# %%
from sklearn.model_selection import StratifiedKFold
# Out:
#        passenger_id  survived  pclass  \
# index
# 1                 1         0       3
# 2                 2         1       1
# 3                 3         1       3
# 4                 4         1       1
# 5                 5         0       3
# ...             ...       ...     ...
# 705             705         0       3
# 706             706         0       2
# 707             707         1       2
# 708             708         1       1
# 709             709         1       1
#
#                                                     name     sex   age  \
# index
# 1                                Braund, Mr. Owen Harris    male  22.0
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                 Heikkinen, Miss. Laina  female  26.0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                               Allen, Mr. William Henry    male  35.0
# ...
